# %%
import pandas as pd
import numpy as np

tesla = pd.read_csv("C:/Users/JAIRO BORJA/Desktop/UNIVERSIDAD/2SEMESTRE/INTELIGENCIA/TSLA.csv")

# %%
tesla
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2010-06-29    3.800000    5.000000    3.508000    4.778000    4.778000
# 1     2010-06-30    5.158000    6.084000    4.660000    4.766000    4.766000
# 2     2010-07-01    5.000000    5.184000    4.054000    4.392000    4.392000
# 3     2010-07-02    4.600000    4.620000    3.742000    3.840000    3.840000
# 4     2010-07-06    4.000000    4.000000    3.166000    3.222000    3.222000
# ...          ...         ...         ...         ...         ...         ...
# 2572  2020-09-16  439.869995  457.790009  435.309998  441.760010  441.760010
# 2573  2020-09-17  415.600006  437.790009  408.000000  423.429993  423.429993
# 2574  2020-09-18  447.940002  451.000000  428.799988  442.149994  442.149994
# 2575  2020-09-21  453.130005  455.679993  407.070007  449.390015  449.390015
# 2576  2020-09-22  429.600006  437.760010  417.600006  424.230011  424.230011
#
#          Volume
# 0      93831500
# ...

# %%
tesla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2577 entries, 0 to 2576
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2577 non-null   object
#  1   Open       2577 non-null   float64
#  2   High       2577 non-null   float64
#  3   Low        2577 non-null   float64
#  4   Close      2577 non-null   float64
#  5   Adj Close  2577 non-null   float64
#  6   Volume     2577 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 141.1+ KB

# %%
tesla.Close
# Out:
# 0         4.778000
# 1         4.766000
# 2         4.392000
# 3         3.840000
# 4         3.222000
#            ...
# 2572    441.760010
# 2573    423.429993
# 2574    442.149994
# 2575    449.390015
# 2576    424.230011
# Name: Close, Length: 2577, dtype: float64

# %%
tesla.Close = tesla.Close.astype(int)

# %%
tesla
# Out:
#             Date        Open        High         Low  Close   Adj Close  \
# 0     2010-06-29    3.800000    5.000000    3.508000      4    4.778000
# 1     2010-06-30    5.158000    6.084000    4.660000      4    4.766000
# 2     2010-07-01    5.000000    5.184000    4.054000      4    4.392000
# 3     2010-07-02    4.600000    4.620000    3.742000      3    3.840000
# 4     2010-07-06    4.000000    4.000000    3.166000      3    3.222000
# ...          ...         ...         ...         ...    ...         ...
# 2572  2020-09-16  439.869995  457.790009  435.309998    441  441.760010
# 2573  2020-09-17  415.600006  437.790009  408.000000    423  423.429993
# 2574  2020-09-18  447.940002  451.000000  428.799988    442  442.149994
# 2575  2020-09-21  453.130005  455.679993  407.070007    449  449.390015
# 2576  2020-09-22  429.600006  437.760010  417.600006    424  424.230011
#
#          Volume
# 0      93831500
# 1      85935500
# 2      41094000
# 3      25699000
# ...

# %%
tesla.Close
# Out:
# 0         4
# 1         4
# 2         4
# 3         3
# 4         3
#        ...
# 2572    441
# 2573    423
# 2574    442
# 2575    449
# 2576    424
# Name: Close, Length: 2577, dtype: int32

# %%
tesla_6 = tesla.loc [tesla['Close'] % 6 == 0]

# %%
tesla_6
# Out:
#             Date        Open        High         Low  Close   Adj Close  \
# 97    2010-11-15    6.044000    6.588000    6.044000      6    6.160000
# 101   2010-11-19    6.032000    6.274000    5.940000      6    6.198000
# 102   2010-11-22    6.314000    6.690000    6.300000      6    6.680000
# 103   2010-11-23    6.658000    7.136000    6.438000      6    6.914000
# 106   2010-11-29    7.082000    7.190000    6.666000      6    6.866000
# ...          ...         ...         ...         ...    ...         ...
# 2556  2020-08-24  425.256012  425.799988  385.503998    402  402.839996
# 2561  2020-08-31  444.609985  500.140015  440.109985    498  498.320007
# 2566  2020-09-08  356.000000  368.739990  329.880005    330  330.209991
# 2567  2020-09-09  356.600006  369.000000  341.510010    366  366.279999
# 2569  2020-09-11  381.940002  382.500000  360.500000    372  372.720001
#
#          Volume
# 97     13114500
# 101     5752500
# 102     7648500
# 103     7889000
# ...

# %%
A = tesla_6.Close > 0

A

tesla_6.loc[ A, 'Close'] = tesla['Close'].mean()

tesla_6
# Out:
# C:\Users\JAIRO BORJA\anaconda3\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#             Date        Open        High         Low      Close   Adj Close  \
# 97    2010-11-15    6.044000    6.588000    6.044000  48.331781    6.160000
# 101   2010-11-19    6.032000    6.274000    5.940000  48.331781    6.198000
# 102   2010-11-22    6.314000    6.690000    6.300000  48.331781    6.680000
# 103   2010-11-23    6.658000    7.136000    6.438000  48.331781    6.914000
# 106   2010-11-29    7.082000    7.190000    6.666000  48.331781    6.866000
# ...          ...         ...         ...         ...        ...         ...
# ...

# %%
tesla_6.loc[ A, 'Close'] = tesla['Close'].min()

tesla_6
# Out:
# C:\Users\JAIRO BORJA\anaconda3\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#             Date        Open        High         Low  Close   Adj Close  \
# 97    2010-11-15    6.044000    6.588000    6.044000    3.0    6.160000
# 101   2010-11-19    6.032000    6.274000    5.940000    3.0    6.198000
# 102   2010-11-22    6.314000    6.690000    6.300000    3.0    6.680000
# 103   2010-11-23    6.658000    7.136000    6.438000    3.0    6.914000
# 106   2010-11-29    7.082000    7.190000    6.666000    3.0    6.866000
# ...          ...         ...         ...         ...    ...         ...
# ...

# %%
tesla_5 = tesla.loc [tesla['Close'] % 5 == 0]
tesla_5
# Out:
#             Date        Open        High         Low  Close   Adj Close  \
# 94    2010-11-10    4.896000    5.994000    4.810000      5    5.872000
# 95    2010-11-11    5.720000    5.820000    5.466000      5    5.608000
# 96    2010-11-12    5.650000    6.100000    5.614000      5    5.968000
# 98    2010-11-16    6.200000    6.280000    5.684000      5    5.934000
# 99    2010-11-17    6.040000    6.150000    5.722000      5    5.898000
# ...          ...         ...         ...         ...    ...         ...
# 2553  2020-08-19  373.000000  382.200012  368.242004    375  375.705994
# 2554  2020-08-20  372.135986  404.398010  371.411987    400  400.365997
# 2558  2020-08-26  412.000000  433.200012  410.726013    430  430.634003
# 2562  2020-09-01  502.140015  502.489990  470.510010    475  475.049988
# 2566  2020-09-08  356.000000  368.739990  329.880005    330  330.209991
#
#          Volume
# 94     15302500
# 95      9726500
# 96     13645500
# 98      6738000
# ...

# %%
tesla_6.loc[ A, 'Close'] = tesla_5['Close'].mean()

tesla_6
# Out:
# C:\Users\JAIRO BORJA\anaconda3\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#             Date        Open        High         Low      Close   Adj Close  \
# 97    2010-11-15    6.044000    6.588000    6.044000  40.863363    6.160000
# 101   2010-11-19    6.032000    6.274000    5.940000  40.863363    6.198000
# 102   2010-11-22    6.314000    6.690000    6.300000  40.863363    6.680000
# 103   2010-11-23    6.658000    7.136000    6.438000  40.863363    6.914000
# 106   2010-11-29    7.082000    7.190000    6.666000  40.863363    6.866000
# ...          ...         ...         ...         ...        ...         ...
# ...

# %%
tesla_7 = tesla.loc [tesla['Close'] % 7 == 0]

tesla_6.loc[ A, 'Close'] = tesla_7['Close'].mean()

tesla_6
# Out:
# C:\Users\JAIRO BORJA\anaconda3\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#             Date        Open        High         Low      Close   Adj Close  \
# 97    2010-11-15    6.044000    6.588000    6.044000  49.833856    6.160000
# 101   2010-11-19    6.032000    6.274000    5.940000  49.833856    6.198000
# 102   2010-11-22    6.314000    6.690000    6.300000  49.833856    6.680000
# 103   2010-11-23    6.658000    7.136000    6.438000  49.833856    6.914000
# 106   2010-11-29    7.082000    7.190000    6.666000  49.833856    6.866000
# ...          ...         ...         ...         ...        ...         ...
# ...

# %%
tesla_6.loc[ A, 'Close'] = tesla_7['Close'].mean() + tesla_5['Close'].mean()

tesla_6
# Out:
# C:\Users\JAIRO BORJA\anaconda3\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#             Date        Open        High         Low      Close   Adj Close  \
# 97    2010-11-15    6.044000    6.588000    6.044000  90.697219    6.160000
# 101   2010-11-19    6.032000    6.274000    5.940000  90.697219    6.198000
# 102   2010-11-22    6.314000    6.690000    6.300000  90.697219    6.680000
# 103   2010-11-23    6.658000    7.136000    6.438000  90.697219    6.914000
# 106   2010-11-29    7.082000    7.190000    6.666000  90.697219    6.866000
# ...          ...         ...         ...         ...        ...         ...
# ...

# %%
import matplotlib.pyplot as plt

# %%
x = tesla['Date']
y = tesla['Open']
y2 = tesla['High']

plt.xlabel('Fecha')

plt.title('Date Vs. Open and High.')

plt.xticks([0, 1288, 2576])

plt.plot(x, y, color = 'b', label = 'Open')
plt.plot(x, y2, color = 'r', label = 'High')
plt.show()

# %%
tesla.High = tesla.High.astype(str)
tesla['High'] = tesla['High'].str.lower()
nuevelen = len(tesla[tesla['High'].str.contains('9')])
nuevelen
# Out:
# 1255

# %%
nueve_1 = tesla.loc [tesla['High'].str.contains('9')]
nueve_1
# Out:
#             Date        Open        High         Low  Close   Adj Close  \
# 23    2010-08-02    4.100000       4.194    4.066000      4    4.184000
# 24    2010-08-03    4.200000        4.39    4.164000      4    4.390000
# 28    2010-08-09    3.980000       3.996    3.890000      3    3.920000
# 29    2010-08-10    3.930000        3.93    3.764000      3    3.806000
# 32    2010-08-13    3.636000        3.69    3.532000      3    3.664000
# ...          ...         ...         ...         ...    ...         ...
# 2568  2020-09-10  386.209991   398.98999  360.559998    371  371.339996
# 2571  2020-09-15  436.559998  461.940002  430.700012    449  449.760010
# 2572  2020-09-16  439.869995  457.790009  435.309998    441  441.760010
# 2573  2020-09-17  415.600006  437.790009  408.000000    423  423.429993
# 2575  2020-09-21  453.130005  455.679993  407.070007    449  449.390015
#
#          Volume
# 23      3590500
# 24      6152500
# 28      4063500
# 29      6406500
# ...

# %%
teslaH = tesla['High'].str.split('.', expand = True)
teslaH
teslaHB = teslaH.rename(columns = {0:'HighA', 1:'HighB'})
teslaHB
# Out:
#      HighA   HighB
# 0        5       0
# 1        6     084
# 2        5     184
# 3        4      62
# 4        4       0
# ...    ...     ...
# 2572   457  790009
# 2573   437  790009
# 2574   451       0
# 2575   455  679993
# 2576   437   76001
#
# [2577 rows x 2 columns]

# %%
teslaHB
# Out:
#      HighA   HighB
# 0        5       0
# 1        6     084
# 2        5     184
# 3        4      62
# 4        4       0
# ...    ...     ...
# 2572   457  790009
# 2573   437  790009
# 2574   451       0
# 2575   455  679993
# 2576   437   76001
#
# [2577 rows x 2 columns]

# %%
teslaHB['HighB'] = teslaHB['HighB'].replace('3', '4')
teslaHB
# Out:
#      HighA   HighB
# 0        5       0
# 1        6     084
# 2        5     184
# 3        4      62
# 4        4       0
# ...    ...     ...
# 2572   457  790009
# 2573   437  790009
# 2574   451       0
# 2575   455  679993
# 2576   437   76001
#
# [2577 rows x 2 columns]

# %%
Omax = tesla['Open'].max()
Omin = tesla['Open'].min()

tesla['OpenNorm'] = tesla['Open'].apply(lambda x: (x - Omin)/(Omax - Omin))

x = tesla['Date']
y = tesla['OpenNorm']


plt.xlabel('Fecha')

plt.title('Date Vs. OpenNorm.')

plt.xticks([0, 1288, 2576])

plt.plot(x, y, color = 'r', label = 'Open')

plt.show()

# %%
tesla.tail(1)
# Out:
#             Date        Open       High         Low  Close   Adj Close  \
# 2576  2020-09-22  429.600006  437.76001  417.600006    424  424.230011
#
#         Volume  OpenNorm
# 2576  73640900  0.854604

# %%
N1 = {'Date':'2020-09-23', 'Open':430, 'High':437, 'Low':417, 'Close':425, 'Adj Close':425, 'Volume':73640901, 'OpenNorm':0.854604}
N2 = {'Date':'2020-09-24', 'Open':431, 'High':438, 'Low':418, 'Close':426, 'Adj Close':426, 'Volume':73640902, 'OpenNorm':0.854605}
N3 = {'Date':'2020-09-25', 'Open':432, 'High':439, 'Low':419, 'Close':427, 'Adj Close':427, 'Volume':73640903, 'OpenNorm':0.854606}
N4 = {'Date':'2020-09-26', 'Open':433, 'High':440, 'Low':420, 'Close':428, 'Adj Close':428, 'Volume':73640904, 'OpenNorm':0.854607}
N5 = {'Date':'2020-09-27', 'Open':433, 'High':440, 'Low':420, 'Close':428, 'Adj Close':428, 'Volume':73640904, 'OpenNorm':0.854607}
N6 = {'Date':'2020-09-28', 'Open':433, 'High':440, 'Low':420, 'Close':428, 'Adj Close':428, 'Volume':73640904, 'OpenNorm':0.854607}
N7 = {'Date':'2020-09-29', 'Open':433, 'High':440, 'Low':420, 'Close':428, 'Adj Close':428, 'Volume':73640904, 'OpenNorm':0.854607}
N8 = {'Date':'2020-09-30', 'Open':433, 'High':440, 'Low':420, 'Close':428, 'Adj Close':428, 'Volume':73640904, 'OpenNorm':0.854607}
N9 = {'Date':'2020-10-01', 'Open':433, 'High':440, 'Low':420, 'Close':428, 'Adj Close':428, 'Volume':73640904, 'OpenNorm':0.854607}
N10 = {'Date':'2020-10-02', 'Open':433, 'High':440, 'Low':420, 'Close':428, 'Adj Close':428, 'Volume':73640904, 'OpenNorm':0.854607}
tesla.append(N1, ignore_index=True)
tesla.append(N2, ignore_index=True)
tesla.append(N3, ignore_index=True)
tesla.append(N4, ignore_index=True)
tesla.append(N5, ignore_index=True)
tesla.append(N6, ignore_index=True)
tesla.append(N7, ignore_index=True)
tesla.append(N8, ignore_index=True)
tesla.append(N9, ignore_index=True)
tesla.append(N10, ignore_index=True)
tesla.tail(10)
# Out:
#             Date        Open        High         Low  Close   Adj Close  \
# 2567  2020-09-09  356.600006       369.0  341.510010    366  366.279999
# 2568  2020-09-10  386.209991   398.98999  360.559998    371  371.339996
# 2569  2020-09-11  381.940002       382.5  360.500000    372  372.720001
# 2570  2020-09-14  380.950012       420.0  373.299988    419  419.619995
# 2571  2020-09-15  436.559998  461.940002  430.700012    449  449.760010
# 2572  2020-09-16  439.869995  457.790009  435.309998    441  441.760010
# 2573  2020-09-17  415.600006  437.790009  408.000000    423  423.429993
# 2574  2020-09-18  447.940002       451.0  428.799988    442  442.149994
# 2575  2020-09-21  453.130005  455.679993  407.070007    449  449.390015
# 2576  2020-09-22  429.600006   437.76001  417.600006    424  424.230011
#
#          Volume  OpenNorm
# 2567   79465800  0.708285
# 2568   84930600  0.767634
# 2569   60717500  0.759076
# 2570   83020600  0.757091
# 2571   97298200  0.868554
# ...
